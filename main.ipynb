# %%
import pandas as pd

# %%
data=pd.read_csv("C:\\Users\\hp\\OneDrive\\Desktop\\New folder\\dataset.csv", quotechar='"', delimiter=',')

# %%
data.head(29)
# Out:
#                               Course  \
# 0             Full Stack Development
# 1                      Web Designing
# 2                  Digital Marketing
# 3                       Data Science
# 4                    Content Writing
# 5                     Graphic Design
# 6                     Cyber Security
# 7                       UI/UX Design
# 8            Social Media Management
# 9   Search Engine Optimization (SEO)
# 10           Artificial Intelligence
# 11                   Web Development
# 12             E-commerce Management
# 13                     Video Editing
# 14                       Photography
# 15                   Online Tutoring
# 16              Translation Services
# 17            Transcription Services
# 18                Virtual Assistance
# 19        Online Survey and Research
# 20               Affiliate Marketing
# 21                      Dropshipping
# 22     Online Coaching or Consulting
# 23                Project Management
# ...

# %%
data.describe()
# Out:
#           Rating
# count  30.000000
# mean    4.543333
# std     0.122287
# min     4.300000
# 25%     4.500000
# 50%     4.500000
# 75%     4.600000
# max     4.800000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Course                   30 non-null     object
#  1   Description              30 non-null     object
#  2   Link                     30 non-null     object
#  3   Rating                   30 non-null     float64
#  4   Instructor/Organization  30 non-null     object
# dtypes: float64(1), object(4)
# memory usage: 1.3+ KB

# %%
data.isnull().sum()
# Out:
# Course                     0
# Description                0
# Link                       0
# Rating                     0
# Instructor/Organization    0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Course', 'Description', 'Link', 'Rating', 'Instructor/Organization'], dtype='object')

# %%
data [['Course', 'Description', 'Link', 'Rating', 'Instructor/Organization']]
# Out:
#                               Course  \
# 0             Full Stack Development
# 1                      Web Designing
# 2                  Digital Marketing
# 3                       Data Science
# 4                    Content Writing
# 5                     Graphic Design
# 6                     Cyber Security
# 7                       UI/UX Design
# 8            Social Media Management
# 9   Search Engine Optimization (SEO)
# 10           Artificial Intelligence
# 11                   Web Development
# 12             E-commerce Management
# 13                     Video Editing
# 14                       Photography
# 15                   Online Tutoring
# 16              Translation Services
# 17            Transcription Services
# 18                Virtual Assistance
# 19        Online Survey and Research
# 20               Affiliate Marketing
# 21                      Dropshipping
# 22     Online Coaching or Consulting
# 23                Project Management
# ...

# %%
new_data = data.drop(columns=['Rating', 'Instructor/Organization'])
new_data
# Out:
#                               Course  \
# 0             Full Stack Development
# 1                      Web Designing
# 2                  Digital Marketing
# 3                       Data Science
# 4                    Content Writing
# 5                     Graphic Design
# 6                     Cyber Security
# 7                       UI/UX Design
# 8            Social Media Management
# 9   Search Engine Optimization (SEO)
# 10           Artificial Intelligence
# 11                   Web Development
# 12             E-commerce Management
# 13                     Video Editing
# 14                       Photography
# 15                   Online Tutoring
# 16              Translation Services
# 17            Transcription Services
# 18                Virtual Assistance
# 19        Online Survey and Research
# 20               Affiliate Marketing
# 21                      Dropshipping
# 22     Online Coaching or Consulting
# 23                Project Management
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv=CountVectorizer(max_features=10000, stop_words='english')
cv
# Out:
# CountVectorizer(max_features=10000, stop_words='english')

# %%
vector=cv.fit_transform(new_data['Description'].values.astype('U')).toarray()

# %%
vector.shape
# Out:
# (30, 75)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.57142857, 0.15430335, 0.16903085, 0.18898224,
#         0.15430335, 0.16903085, 0.14285714, 0.15430335, 0.16903085,
#         0.13363062, 0.84515425, 0.16903085, 0.15430335, 0.18898224,
#         0.18898224, 0.21821789, 0.21821789, 0.18898224, 0.21821789,
#         0.18898224, 0.18898224, 0.18898224, 0.18898224, 0.18898224,
#         0.21821789, 0.18898224, 0.21821789, 0.18898224, 0.18898224],
#        [0.57142857, 1.        , 0.15430335, 0.16903085, 0.18898224,
#         0.15430335, 0.16903085, 0.14285714, 0.15430335, 0.16903085,
#         0.13363062, 0.6761234 , 0.16903085, 0.15430335, 0.18898224,
#         0.18898224, 0.21821789, 0.21821789, 0.18898224, 0.21821789,
#         0.18898224, 0.18898224, 0.18898224, 0.18898224, 0.18898224,
#         0.21821789, 0.18898224, 0.21821789, 0.18898224, 0.18898224],
#        [0.15430335, 0.15430335, 1.        , 0.18257419, 0.20412415,
#         0.16666667, 0.18257419, 0.15430335, 0.5       , 0.36514837,
# ...

# %%
new_data[new_data['Course']=="Cyber Security"]
# Out:
#            Course                                  Description  \
# 6  Cyber Security  Learn security frameworks & threat analysis
#
#                                                 Link
# 6  https://www.coursera.org/specializations/cyber...

# %%
distance = sorted(list(enumerate(similarity[2])), reverse=True, key=lambda vector:vector[1])
for i in distance[0:5]:
    print(new_data.iloc[i[0]].Course)
# Out:
# Digital Marketing
# Social Media Management
# Search Engine Optimization (SEO)
# Translation Services
# Transcription Services

# %%
def recommend(data):
    index=new_data[new_data['Course']==data].index[0]
    distance = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda vector:vector[1])
    for i in distance[0:5]:
      print(new_data.iloc[i[0]].Course)

# %%
recommend("Web Designing")
# Out:
# Web Designing
# Web Development
# Full Stack Development
# Translation Services
# Transcription Services

# %%
import pickle

# %%
pickle.dump(new_data, open('dataset_list.pkl', 'wb'))

# %%
pickle.dump(similarity, open('similarity.pkl', 'wb'))

# %%
pickle.load(open('dataset_list.pkl', 'rb'))
# Out:
#                               Course  \
# 0             Full Stack Development
# 1                      Web Designing
# 2                  Digital Marketing
# 3                       Data Science
# 4                    Content Writing
# 5                     Graphic Design
# 6                     Cyber Security
# 7                       UI/UX Design
# 8            Social Media Management
# 9   Search Engine Optimization (SEO)
# 10           Artificial Intelligence
# 11                   Web Development
# 12             E-commerce Management
# 13                     Video Editing
# 14                       Photography
# 15                   Online Tutoring
# 16              Translation Services
# 17            Transcription Services
# 18                Virtual Assistance
# 19        Online Survey and Research
# 20               Affiliate Marketing
# 21                      Dropshipping
# 22     Online Coaching or Consulting
# 23                Project Management
# ...
